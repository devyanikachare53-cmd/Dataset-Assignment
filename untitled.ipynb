# %% [markdown]
# <a href="https://colab.research.google.com/github/devyanikachare53-cmd/Dataset-Assignment/blob/main/untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9efcc506-65ab-4bc0-a071-37f031be4c68" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9efcc506-65ab-4bc0-a071-37f031be4c68">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Q2. (Dataset Selection & Initial Exploration)
# Load the dataset and show first 10 rows.
# Write 5-6 lines explaining why you chose this dataset and what continuous
# value you want to predict.

# %%
df = pd.read_csv('BIKE DETAILS.csv')

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.head()
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN

# %%
df.tail()
# Out:
#                     name  selling_price  year seller_type      owner  \
# 1056           Activa 3g          17000  2010  Individual  1st owner
# 1057    Honda CB twister          16000  2012  Individual  1st owner
# 1058  Bajaj Discover 125          15000  2013  Individual  2nd owner
# 1059      Honda CB Shine          12000  2009  Individual  1st owner
# 1060    Bajaj Pulsar 150          10000  2008  Individual  1st owner
#
#       km_driven  ex_showroom_price
# 1056     500000            52000.0
# 1057      33000            51000.0
# 1058      35000            57000.0
# 1059      53000            58000.0
# 1060      92233            75000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  626 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 58.2+ KB

# %%
df.describe()
# Out:
#        selling_price         year      km_driven  ex_showroom_price
# count    1061.000000  1061.000000    1061.000000       6.260000e+02
# mean    59638.151744  2013.867107   34359.833176       8.795871e+04
# std     56304.291973     4.301191   51623.152702       7.749659e+04
# min      5000.000000  1988.000000     350.000000       3.049000e+04
# 25%     28000.000000  2011.000000   13500.000000       5.485200e+04
# 50%     45000.000000  2015.000000   25000.000000       7.275250e+04
# 75%     70000.000000  2017.000000   43000.000000       8.703150e+04
# max    760000.000000  2020.000000  880000.000000       1.278000e+06

# %%
df.shape
# Out:
# (1061, 7)

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name                  object
# selling_price          int64
# year                   int64
# seller_type           object
# owner                 object
# km_driven              int64
# ex_showroom_price    float64
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %%
df.fillna(df.select_dtypes(include='number').mean(), inplace=True)

# %%
print(df.isnull().sum())
# Out:
# name                 0
# selling_price        0
# year                 0
# seller_type          0
# owner                0
# km_driven            0
# ex_showroom_price    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(6)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# name                 0
# selling_price        0
# year                 0
# seller_type          0
# owner                0
# km_driven            0
# ex_showroom_price    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))

plt.subplot(2,3,1)
plt.hist(df['selling_price'], bins=30)
plt.title("Selling Price")

plt.subplot(2,3,2)
plt.hist(df['year'], bins=30)
plt.title("Year")

plt.subplot(2,3,3)
plt.hist(df['ex_showroom_price'], bins=30)
plt.title("Ex-Shwroom Price")

plt.subplot(2,3,4)
plt.hist(df['km_driven'], bins=30)
plt.title("Km-Driven")


plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18,8))

# Fuel Type
plt.subplot(1,3,1)
sns.countplot(x='name', data=df)
plt.title("Name of the model")
# plt.xticks(rotation=45)

# Seller Type
plt.subplot(1,3,2)
sns.countplot(x='seller_type', data=df)
plt.title("Seller Type")

# Owner
plt.subplot(1,3,3)
sns.countplot(x='owner', data=df)
plt.title("Owner")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
X = df.drop("selling_price", axis =1)
X
Y = df["selling_price"]
Y
# Out:
# 0       175000
# 1        45000
# 2       150000
# 3        65000
# 4        20000
#          ...
# 1056     17000
# 1057     16000
# 1058     15000
# 1059     12000
# 1060     10000
# Name: selling_price, Length: 1055, dtype: int64

# %%
print("Before Encoding:")
print(df[['name', 'owner']].head())
# Out:
# Before Encoding:
#                                   name      owner
# 0            Royal Enfield Classic 350  1st owner
# 1                            Honda Dio  1st owner
# 2  Royal Enfield Classic Gunmetal Grey  1st owner
# 3    Yamaha Fazer FI V 2.0 [2016-2018]  1st owner
# 4                Yamaha SZ [2013-2014]  2nd owner

# %%
encoded_input = pd.get_dummies(X)
print("\nAfter Encoding:")
encoded_input.head()
# Out:
# After Encoding:
#    year  km_driven  ex_showroom_price  name_Activa 3g  name_Activa 4g  \
# 0  2019        350       87958.714058           False           False
# 1  2017       5650       87958.714058           False           False
# 2  2018      12000      148114.000000           False           False
# 3  2015      23000       89643.000000           False           False
# 4  2011      21000       87958.714058           False           False
#
#    name_Aprilia SR 125  name_BMW G310GS  name_Bajaj  ct 100  \
# 0                False            False               False
# 1                False            False               False
# 2                False            False               False
# 3                False            False               False
# 4                False            False               False
#
#    name_Bajaj Avenger 150  name_Bajaj Avenger 150 street  ...  \
# 0                   False                          False  ...
# ...

# %%
# Before Encoding:

# Categorical columns contained text values such as bike names and owner types.

# After Encoding:

# One-Hot Encoding converted each category into separate binary (0/1) columns.

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
numeric_col = ["year","km_driven",	"ex_showroom_price"]
encoded_input[numeric_col] = scale.fit_transform(encoded_input[numeric_col])
encoded_input
# Out:
#           year  km_driven  ex_showroom_price  name_Activa 3g  name_Activa 4g  \
# 0     1.191746  -0.656795          -0.001009           False           False
# 1     0.727029  -0.554248          -0.001009           False           False
# 2     0.959388  -0.431385           1.007760           False           False
# 3     0.262312  -0.218553           0.027235           False           False
# 4    -0.667122  -0.257250          -0.001009           False           False
# ...        ...        ...                ...             ...             ...
# 1056 -0.899481   9.010649          -0.604016            True           False
# 1057 -0.434764  -0.025068          -0.620785           False           False
# 1058 -0.202405   0.013628          -0.520169           False           False
# 1059 -1.131840   0.361900          -0.503399           False           False
# 1060 -1.364198   1.120997          -0.218319           False           False
#
# ...

# %%
encoded_input.head(5)
# Out:
#        year  km_driven  ex_showroom_price  name_Activa 3g  name_Activa 4g  \
# 0  1.191746  -0.656795          -0.001009           False           False
# 1  0.727029  -0.554248          -0.001009           False           False
# 2  0.959388  -0.431385           1.007760           False           False
# 3  0.262312  -0.218553           0.027235           False           False
# 4 -0.667122  -0.257250          -0.001009           False           False
#
#    name_Aprilia SR 125  name_BMW G310GS  name_Bajaj  ct 100  \
# 0                False            False               False
# 1                False            False               False
# 2                False            False               False
# 3                False            False               False
# 4                False            False               False
#
#    name_Bajaj Avenger 150  name_Bajaj Avenger 150 street  ...  \
# 0                   False                          False  ...
# ...
